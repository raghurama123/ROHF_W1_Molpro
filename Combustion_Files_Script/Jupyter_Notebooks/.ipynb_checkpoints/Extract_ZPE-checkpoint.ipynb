# %%
import re
import os
import numpy as np
import pandas as pd
from pandas import DataFrame as df

au2kcal = 627.50957099203276

# %%
file = open('../ETHYL/ETHYL_OPT_FILES/Mol_01.log',"r")
for line in file:
    if re.search('Thermal correction to Enthalpy=',line):
        print(line.split()[4])
# Out:
# 0.063963

# %%
SYSTEMS = ['ETHYL','ISOPROPYL','ISOBUTYL','TERTBUTYL','NEOPENTYL','CYCLOHEXYL','CYCLOHEXENYL',
           'CYCLOHEXADIENYL','CYCLOHEPTADIENYL']

MOLECULES = ['Mol_01','Mol_02','Mol_03','Mol_04','Mol_05']
for isystem in SYSTEMS:
    DIR_OUT = '../'+isystem+'/'+isystem+'_DATA/'+isystem+'_ZPE.dat'
    OUT_FILE = open(DIR_OUT,"w")
    print(OUT_FILE)
    for imol in MOLECULES:
        DIR = '../'+isystem+'/'+isystem+'_OPT_FILES/'
        FILENAME = DIR+imol+'.log'
        file = open(FILENAME,"r")
        for line in file:
            if re.search('Zero-point correction=',line):
                OUT_FILE.write((line.split()[2]))
                OUT_FILE.write("\n")
                print(line.split()[2])
    OUT_FILE.close()
# Out:
# <_io.TextIOWrapper name='../ETHYL/ETHYL_DATA/ETHYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.059042
# 0.071179
# 0.067714
# 0.057201
# 0.050920
# <_io.TextIOWrapper name='../ISOPROPYL/ISOPROPYL_DATA/ISOPROPYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.087533
# 0.099090
# 0.095946
# 0.085133
# 0.079401
# <_io.TextIOWrapper name='../ISOBUTYL/ISOBUTYL_DATA/ISOBUTYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.116069
# 0.127821
# 0.124397
# 0.112709
# 0.107452
# <_io.TextIOWrapper name='../TERTBUTYL/TERTBUTYL_DATA/TERTBUTYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.115950
# 0.126483
# 0.123494
# 0.112709
# 0.107452
# <_io.TextIOWrapper name='../NEOPENTYL/NEOPENTYL_DATA/NEOPENTYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.143825
# 0.155376
# 0.152475
# 0.142063
# 0.136797
# <_io.TextIOWrapper name='../CYCLOHEXYL/CYCLOHEXYL_DATA/CYCLOHEXYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.154917
# 0.165700
# 0.162473
# 0.151137
# 0.145794
# <_io.TextIOWrapper name='../CYCLOHEXENYL/CYCLOHEXENYL_DATA/CYCLOHEXENYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.132038
# 0.141788
# 0.138916
# 0.127138
# 0.122015
# <_io.TextIOWrapper name='../CYCLOHEXADIENYL/CYCLOHEXADIENYL_DATA/CYCLOHEXADIENYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.108473
# 0.117892
# 0.116468
# 0.103788
# 0.100391
# <_io.TextIOWrapper name='../CYCLOHEPTADIENYL/CYCLOHEPTADIENYL_DATA/CYCLOHEPTADIENYL_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.136183
# 0.146968
# 0.145552
# 0.132478
# 0.127758

# %%
SYSTEMS = ['ETHYL','ISOPROPYL','ISOBUTYL','TERTBUTYL','NEOPENTYL','CYCLOHEXYL','CYCLOHEXENYL',
           'CYCLOHEXADIENYL','CYCLOHEPTADIENYL']

MOLECULES = ['Mol_01','Mol_02','Mol_03','Mol_04','Mol_05']
for isystem in SYSTEMS:
    DIR_OUT = '../'+isystem+'/'+isystem+'_DATA/'+isystem+'_Hcorr.dat'
    OUT_FILE = open(DIR_OUT,"w")
    print(OUT_FILE)
    for imol in MOLECULES:
        DIR = '../'+isystem+'/'+isystem+'_OPT_FILES/'
        FILENAME = DIR+imol+'.log'
        file = open(FILENAME,"r")
        for line in file:
            if re.search('Thermal correction to Enthalpy=',line):
                OUT_FILE.write((line.split()[4]))
                OUT_FILE.write("\n")
                print(line.split()[4])
    OUT_FILE.close()
# Out:
# <_io.TextIOWrapper name='../ETHYL/ETHYL_DATA/ETHYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.063963
# 0.077180
# 0.074576
# 0.061300
# 0.054903
# <_io.TextIOWrapper name='../ISOPROPYL/ISOPROPYL_DATA/ISOPROPYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.093688
# 0.106285
# 0.104029
# 0.090500
# 0.084430
# <_io.TextIOWrapper name='../ISOBUTYL/ISOBUTYL_DATA/ISOBUTYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.123090
# 0.136230
# 0.134029
# 0.119423
# 0.113701
# <_io.TextIOWrapper name='../TERTBUTYL/TERTBUTYL_DATA/TERTBUTYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.123271
# 0.135010
# 0.132822
# 0.119423
# 0.113701
# <_io.TextIOWrapper name='../NEOPENTYL/NEOPENTYL_DATA/NEOPENTYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.152136
# 0.165099
# 0.162790
# 0.149776
# 0.143673
# <_io.TextIOWrapper name='../CYCLOHEXYL/CYCLOHEXYL_DATA/CYCLOHEXYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.161936
# 0.174342
# 0.171975
# 0.158075
# 0.152252
# <_io.TextIOWrapper name='../CYCLOHEXENYL/CYCLOHEXENYL_DATA/CYCLOHEXENYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.138487
# 0.150156
# 0.148130
# 0.133867
# 0.128134
# <_io.TextIOWrapper name='../CYCLOHEXADIENYL/CYCLOHEXADIENYL_DATA/CYCLOHEXADIENYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.114468
# 0.125927
# 0.124878
# 0.109894
# 0.105714
# <_io.TextIOWrapper name='../CYCLOHEPTADIENYL/CYCLOHEPTADIENYL_DATA/CYCLOHEPTADIENYL_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.143848
# 0.156257
# 0.155105
# 0.139911
# 0.134429

# %%
SYSTEMS = ['ETHYL','ISOPROPYL','ISOBUTYL','TERTBUTYL','NEOPENTYL','CYCLOHEXYL','CYCLOHEXENYL',
           'CYCLOHEXADIENYL','CYCLOHEPTADIENYL']

MOLECULES = ['TS_01','TS_02','TS_03','TS_04']
for isystem in SYSTEMS:
    DIR_OUT = '../'+isystem+'/'+isystem+'_DATA/'+isystem+'_TS_ZPE.dat'
    OUT_FILE = open(DIR_OUT,"w")
    print(OUT_FILE)
    for imol in MOLECULES:
        DIR = '../'+isystem+'/'+isystem+'_OPT_FILES/'
        FILENAME = DIR+imol+'.log'
        file = open(FILENAME,"r")
        for line in file:
            if re.search('Zero-point correction=',line):
                OUT_FILE.write((line.split()[2]))
                OUT_FILE.write("\n")
                print(line.split()[2])
    OUT_FILE.close()
# Out:
# <_io.TextIOWrapper name='../ETHYL/ETHYL_DATA/ETHYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.065123
# 0.064940
# 0.067367
# 0.066412
# <_io.TextIOWrapper name='../ISOPROPYL/ISOPROPYL_DATA/ISOPROPYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.092786
# 0.092782
# 0.095223
# 0.094298
# <_io.TextIOWrapper name='../ISOBUTYL/ISOBUTYL_DATA/ISOBUTYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.121503
# 0.120902
# 0.123134
# 0.122165
# <_io.TextIOWrapper name='../TERTBUTYL/TERTBUTYL_DATA/TERTBUTYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.120166
# 0.120363
# 0.122756
# 0.121830
# <_io.TextIOWrapper name='../NEOPENTYL/NEOPENTYL_DATA/NEOPENTYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.149353
# 0.147355
# 0.150439
# 0.151112
# <_io.TextIOWrapper name='../CYCLOHEXYL/CYCLOHEXYL_DATA/CYCLOHEXYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.159858
# 0.159076
# 0.161432
# 0.160470
# <_io.TextIOWrapper name='../CYCLOHEXENYL/CYCLOHEXENYL_DATA/CYCLOHEXENYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.135684
# 0.135031
# 0.137650
# 0.136642
# <_io.TextIOWrapper name='../CYCLOHEXADIENYL/CYCLOHEXADIENYL_DATA/CYCLOHEXADIENYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.112800
# 0.112898
# 0.115581
# 0.113650
# <_io.TextIOWrapper name='../CYCLOHEPTADIENYL/CYCLOHEPTADIENYL_DATA/CYCLOHEPTADIENYL_TS_ZPE.dat' mode='w' encoding='UTF-8'>
# 0.141441
# 0.140161
# 0.143415
# 0.142198

# %%
SYSTEMS = ['ETHYL','ISOPROPYL','ISOBUTYL','TERTBUTYL','NEOPENTYL','CYCLOHEXYL','CYCLOHEXENYL',
           'CYCLOHEXADIENYL','CYCLOHEPTADIENYL']

MOLECULES = ['TS_01','TS_02','TS_03','TS_04']
for isystem in SYSTEMS:
    DIR_OUT = '../'+isystem+'/'+isystem+'_DATA/'+isystem+'_TS_Hcorr.dat'
    OUT_FILE = open(DIR_OUT,"w")
    print(OUT_FILE)
    for imol in MOLECULES:
        DIR = '../'+isystem+'/'+isystem+'_OPT_FILES/'
        FILENAME = DIR+imol+'.log'
        file = open(FILENAME,"r")
        for line in file:
            if re.search('Thermal correction to Enthalpy=',line):
                OUT_FILE.write((line.split()[4]))
                OUT_FILE.write("\n")
                print(line.split()[4])
    OUT_FILE.close()
# Out:
# <_io.TextIOWrapper name='../ETHYL/ETHYL_DATA/ETHYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.070250
# 0.070448
# 0.073664
# 0.072925
# <_io.TextIOWrapper name='../ISOPROPYL/ISOPROPYL_DATA/ISOPROPYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.099331
# 0.099775
# 0.102933
# 0.102015
# <_io.TextIOWrapper name='../ISOBUTYL/ISOBUTYL_DATA/ISOBUTYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.129428
# 0.129299
# 0.132551
# 0.131779
# <_io.TextIOWrapper name='../TERTBUTYL/TERTBUTYL_DATA/TERTBUTYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.128059
# 0.128855
# 0.131817
# 0.130850
# <_io.TextIOWrapper name='../NEOPENTYL/NEOPENTYL_DATA/NEOPENTYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.158135
# 0.157364
# 0.160625
# 0.161139
# <_io.TextIOWrapper name='../CYCLOHEXYL/CYCLOHEXYL_DATA/CYCLOHEXYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.167860
# 0.167802
# 0.170832
# 0.169964
# <_io.TextIOWrapper name='../CYCLOHEXENYL/CYCLOHEXENYL_DATA/CYCLOHEXENYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.143525
# 0.143571
# 0.146750
# 0.145835
# <_io.TextIOWrapper name='../CYCLOHEXADIENYL/CYCLOHEXADIENYL_DATA/CYCLOHEXADIENYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.120203
# 0.121150
# 0.123843
# 0.122283
# <_io.TextIOWrapper name='../CYCLOHEPTADIENYL/CYCLOHEPTADIENYL_DATA/CYCLOHEPTADIENYL_TS_Hcorr.dat' mode='w' encoding='UTF-8'>
# 0.149901
# 0.149338
# 0.153142
# 0.152274
